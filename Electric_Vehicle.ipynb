# %%
import csv

# %%
filename = "Electric_Vehicle_Charging_Stations.csv"

# %%
keys = {'Station Name','New Georeferenced Column'}

# %%
records = []

# %%
with open(filename, "r") as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        records.append({key: row[key] for key in keys})

# %%
print(records[0])
# Out:
# {'New Georeferenced Column': 'POINT (-73.4764687 41.072882)', 'Station Name': 'BMW OF DARIEN'}

# %%
for record in records:
    longitude, latitude = record['New Georeferenced Column'].split("(")[-1].split(")")[0].split()
    record['longitude'] = float(longitude)
    record['latitude'] = float(latitude)

# %%
records[0]
# Out:
# {'New Georeferenced Column': 'POINT (-73.4764687 41.072882)',
#  'Station Name': 'BMW OF DARIEN',
#  'longitude': -73.4764687,
#  'latitude': 41.072882}

# %%
import folium
from folium.plugins import FastMarkerCluster

map = folium.Map(location=[41.5025,-72.699997],zoom_start=9)

latitudes = [a['latitude'] for a in records]
longitudes = [a['longitude'] for a in records]

FastMarkerCluster(data=(list(zip(latitudes,longitudes)))).add_to(map)
map

# for record in records:
#     coords = (record['latitude'],record['longitude'])
#     folium.Marker(coords,popup=record['Station Name']).add_to(map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2662057b8a3072f4de94915ec828dead {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2662057b8a3072f4de94915ec828dead&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2662057b8a3072f4de94915ec828dead = L.map(
#                 &quot;map_2662057b8a3072f4de94915ec828dead&quot;,
#                 {
#                     center: [41.5025, -72.699997],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f3b602946a9e5c1eeeb43ae64742f49b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2662057b8a3072f4de94915ec828dead);
#
#
#             var fast_marker_cluster_44c221aa3c8a00e9dfc8254de48ee0bd = (function(){
#
#                 var callback = function (row) {
#                     var icon = L.AwesomeMarkers.icon();
#                     var marker = L.marker(new L.LatLng(row[0], row[1]));
#                     marker.setIcon(icon);
#                     return marker;
#                 };
#
#                 var data = [[41.072882, -73.4764687], [41.527367, -72.773473], [41.44548100000001, -73.065583], [41.3102778, -72.3825], [41.143125, -73.264511], [41.525611, -72.0741188], [41.722672, -72.759717], [41.711717, -72.6086744], [41.072919, -73.476189], [41.365973, -72.026147], [41.550922, -73.025659], [41.730405, -72.79061800000001], [41.299792, -73.106051], [41.4618954, -72.8231924], [41.650999, -72.679679], [41.078282, -73.466318], [41.297487000000004, -72.926722], [41.251966, -73.297822], [41.80452, -72.562282], [41.988528, -73.138786], [41.37356200000001, -71.961361], [41.929342, -72.670609], [41.811817, -72.261825], [41.263416, -72.560456], [41.649365, -72.770648], [41.768396, -72.195701], [41.8750604, -73.1049768], [41.7640244, -73.070231], [41.317722, -72.065994], [41.5871612, -72.6824246], [41.176442, -73.230597], [41.728247, -72.188445], [41.28006, -72.43786], [41.353572, -72.870574], [41.2975353, -72.9270748], [41.803497, -73.12122300000001], [41.699374, -72.894672], [41.296212, -72.781436], [41.800421, -72.242231], [41.814316, -72.507845], [41.536236, -72.797226], [41.306474, -72.948514], [41.537218, -72.796702], [41.664356600000005, -72.7788286], [41.287164, -72.657682], [41.549361, -73.02614], [41.983904, -72.489406], [41.765434, -72.684758], [41.563917, -72.711926], [41.467376, -72.817586], [41.766656, -72.676489], [41.198568, -73.132624], [41.331744, -71.906918], [41.145215689458, -73.35947443366], [
= L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_736ee209cf316ae6cbecebb2dfb22e4a = $(`&lt;div id=&quot;html_736ee209cf316ae6cbecebb2dfb22e4a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dunkinâ€™ - Tesla Supercharger&lt;/div&gt;`)[0];
#                 popup_3dcc72149986d1103d04cdc7c4a4ee3c.setContent(html_736ee209cf316ae6cbecebb2dfb22e4a);
#
#
#
#         marker_865b84477cc85bf341c4dfda202c1b0f.bindPopup(popup_3dcc72149986d1103d04cdc7c4a4ee3c)
#         ;
#
#
#
#
#             var marker_fbc62e4cf620563f47233d71a3fe52d9 = L.marker(
#                 [41.44548100000001, -73.065583],
#                 {}
#             ).addTo(map_66a5e0c801dcc345f97995ae6f555bc8);
#
#
#         var popup_8585dc70b437fd5e536715217ef4d2c0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2f1e1926310c2eca7afa410061c06d73 = $(`&lt;div id=&quot;html_2f1e1926310c2eca7afa410061c06d73&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Town of Beacon Falls - Commuter Lot&lt;/div&gt;`)[0];
#                 popup_8585dc70b437fd5e536715217ef4d2c0.setContent(html_2f1e1926310c2eca7afa410061c06d73);
#
#
#
#         marker_fbc62e4cf620563f47233d71a3fe52d9.bindPopup(popup_8585dc70b437fd5e536715217ef4d2c0)
#         ;
#
#
#
#
#             var marker_c0c27bd8f2b050de346e02777703e528 = L.marker(
#                 [41.3102778, -72.3825],
#                 {}
#             ).addTo(map_66a5e0c801dcc345f97995ae6f555bc8);
#
#
#         var popup_83da6cb403412f7d8fd0b5cc28ca2d38 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a36116ca11028fcab115fcaeff631a7b = $(`&lt;div id=&quot;html_a36116ca11028fcab115fcaeff631a7b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;OLD SAYBROOK VW&lt;/div&gt;`)[0];
#                 popup_83da6cb403412f7d8fd0b5cc28ca2d38.setContent(html_a36116ca11028fcab115fcaeff631a7b);
#
#
#
#         marker_c0c27bd8f2b050de346e02777703e528.bindPopup(popup_83da6cb403412f7d8fd0b5cc28ca2d38)
#         ;
#
#
#
#
#             var marker_16c959317fa4df5ae60ba8ae3a37e7df = L.marker(
#                 [41.143125, -73.264511],
#                 {}
#             ).addTo(map_66a5e0c801dcc345f97995ae6f555bc8);
#
#
#         var popup_a394986c8914938693b955b16419dbaa = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8c08e7d76917ceada69c766086f7b8f9 = $(`&lt;div id=&quot;html_8c08e7d76917ceada69c766086f7b8f9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Fairfield Rail Station&lt;/div&gt;`)[0];
#                 popup_a394986c8914938693b955b16419dbaa.setContent(html_8c08e7d76917ceada69c766086f7b8f9);
#
#
#
#         marker_16c959317fa4df5ae60ba8ae3a37e7df.bindPopup(popup_a394986c8914938693b955b16419dbaa)
#         ;
#
#
#
#
#             var marker_b1985859a63135852268d0221b0774a5 = L.mar
